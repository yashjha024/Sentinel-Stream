# %% [markdown]
# # Federated Learning with FedAdam for Cybersecurity Dataset
#
# This notebook implements federated learning using FedAdam optimization for cybersecurity attack detection.

# %%
import torch

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Import our federated learning modules
from federated_learning.models import CyberSecurityNet
from federated_learning.client import FedClient
from federated_learning.server import FedAdamServer
from federated_learning.utils import prepare_data, create_data_loaders

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
print(f"PyTorch version: {torch.__version__}")
# Out:
# Using device: cuda
# PyTorch version: 2.5.1+cu121

# %% [markdown]
# ## Data Preparation
#
# Loading and preprocessing the majority and minority datasets for federated learning.

# %%
# Prepare data for both majority and minority datasets
print("Preparing majority dataset...")
X_train_maj, X_test_maj, y_train_maj, y_test_maj, scaler_maj, le_maj = prepare_data('output/majority.csv')

print("\nPreparing minority dataset...")
X_train_min, X_test_min, y_train_min, y_test_min, scaler_min, le_min = prepare_data('output/minority.csv')

print(f"\nDataset Information:")
print(f"Majority dataset - Train: {X_train_maj.shape}, Test: {X_test_maj.shape}")
print(f"Minority dataset - Train: {X_train_min.shape}, Test: {X_test_min.shape}")
print(f"Number of features: {X_train_maj.shape[1]}")
print(f"Majority classes: {len(np.unique(y_train_maj))}")
print(f"Minority classes: {len(np.unique(y_train_min))}")

# Display class distributions
print(f"\nMajority dataset class distribution:")
unique_maj, counts_maj = np.unique(y_train_maj, return_counts=True)
for cls, count in zip(unique_maj, counts_maj):
    print(f"  Class {cls} ({le_maj.classes_[cls]}): {count} samples")

print(f"\nMinority dataset class distribution:")
unique_min, counts_min = np.unique(y_train_min, return_counts=True)
for cls, count in zip(unique_min, counts_min):
    print(f"  Class {cls} ({le_min.classes_[cls]}): {count} samples")
# Out:
# Preparing majority dataset...
#
# Preparing minority dataset...
#
# Dataset Information:
# Majority dataset - Train: (273688, 68), Test: (68423, 68)
# Minority dataset - Train: (1422, 68), Test: (356, 68)
# Number of features: 68
# Majority classes: 4
# Minority classes: 4
#
# Majority dataset class distribution:
#   Class 0 (0.0): 97553 samples
#   Class 1 (1.0): 78503 samples
#   Class 2 (2.0): 54739 samples
#   Class 3 (3.0): 42893 samples
#
# Minority dataset class distribution:
#   Class 0 (4.0): 1124 samples
#   Class 1 (5.0): 153 samples
#   Class 2 (6.0): 131 samples
#   Class 3 (7.0): 14 samples

# %%
# Create data loaders for each client
batch_size = 64

train_loader_maj, test_loader_maj = create_data_loaders(
    X_train_maj, y_train_maj, X_test_maj, y_test_maj, batch_size
)

train_loader_min, test_loader_min = create_data_loaders(
    X_train_min, y_train_min, X_test_min, y_test_min, batch_size
)

print("Data loaders created successfully!")
print(f"Majority client - Train batches: {len(train_loader_maj)}, Test batches: {len(test_loader_maj)}")
print(f"Minority client - Train batches: {len(train_loader_min)}, Test batches: {len(test_loader_min)}")
# Out:
# Data loaders created successfully!
# Majority client - Train batches: 4277, Test batches: 1070
# Minority client - Train batches: 23, Test batches: 6

# %% [markdown]
# ## Model Setup
#
# Setting up the neural network architecture and determining the number of classes.

# %%
# Model parameters
input_dim = X_train_maj.shape[1]
num_classes_maj = len(np.unique(y_train_maj))
num_classes_min = len(np.unique(y_train_min))

# For federated learning, we'll use the maximum number of classes
max_classes = max(num_classes_maj, num_classes_min)

print(f"Model Configuration:")
print(f"Input dimension: {input_dim}")
print(f"Number of classes (majority): {num_classes_maj}")
print(f"Number of classes (minority): {num_classes_min}")
print(f"Using max classes for model: {max_classes}")

# Display model architecture
sample_model = CyberSecurityNet(input_dim, max_classes)
print(f"\nModel Architecture:")
print(sample_model)

# Count parameters
total_params = sum(p.numel() for p in sample_model.parameters())
trainable_params = sum(p.numel() for p in sample_model.parameters() if p.requires_grad)
print(f"\nTotal parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
# Out:
# Model Configuration:
# Input dimension: 68
# Number of classes (majority): 4
# Number of classes (minority): 4
# Using max classes for model: 4
#
# Model Architecture:
# CyberSecurityNet(
#   (fc1): Linear(in_features=68, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=4, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )
#
# Total parameters: 19,300
# Trainable parameters: 19,300

# %% [markdown]
# ## Federated Learning Setup
#
# Initializing the server and clients for federated learning with FedAdam optimization.

# %%
# Initialize global model
global_model = CyberSecurityNet(input_dim, max_classes)



# Initialize server with FedAdam
server = FedAdamServer(
    model=global_model,
    beta1=0.9,      # momentum parameter
    beta2=0.999,    # second moment parameter
    eta=0.01,       # server learning rate
    tau=1e-3        # regularization parameter
)

# Initialize clients
client_majority = FedClient(
    client_id="majority",
    model=CyberSecurityNet(input_dim, max_classes),
    train_loader=train_loader_maj,
    test_loader=test_loader_maj,
    device=device
)

client_minority = FedClient(
    client_id="minority",
    model=CyberSecurityNet(input_dim, max_classes),
    train_loader=train_loader_min,
    test_loader=test_loader_min,
    device=device
)

clients = [client_majority, client_minority]

print("Federated learning setup completed!")
print(f"Server: FedAdam with β1={server.beta1}, β2={server.beta2}, η={server.eta}")
print(f"Number of clients: {len(clients)}")
for client in clients:
    print(f"  - Client '{client.client_id}': {len(client.train_loader.dataset)} training samples")
# Out:
# Federated learning setup completed!
# Server: FedAdam with β1=0.9, β2=0.999, η=0.01
# Number of clients: 2
#   - Client 'majority': 273688 training samples
#   - Client 'minority': 1422 training samples

# %% [markdown]
# ## Training Configuration
#
# Setting up training parameters and metrics tracking.

# %%
# Training parameters
num_rounds = 50
local_epochs = 5
learning_rate = 0.001

# Tracking metrics
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

print(f"Training Configuration:")
print(f"Number of communication rounds: {num_rounds}")
print(f"Local epochs per round: {local_epochs}")
print(f"Client learning rate: {learning_rate}")
print(f"Batch size: {batch_size}")
print("\n" + "="*60)
print("Starting Federated Training...")
print("="*60)
# Out:
# Training Configuration:
# Number of communication rounds: 50
# Local epochs per round: 5
# Client learning rate: 0.001
# Batch size: 64
#
# ============================================================
# Starting Federated Training...
# ============================================================

# %%
import time

start_time = time.time()

for round_num in range(num_rounds):
    round_start_time = time.time()
    print(f"\n🔄 Round {round_num + 1}/{num_rounds}")
    
    # Get global model parameters
    global_params = server.get_parameters()
    
    # Client training
    client_results = []
    
    for client in clients:
        # Set global parameters to client
        client.set_parameters(global_params)
        
        # Local training
        loss, num_samples = client.train(epochs=local_epochs, lr=learning_rate)
        
        # Get updated parameters
        updated_params = client.get_parameters()
        
        client_results.append((updated_params, num_samples, loss))
        print(f"  📱 Client {client.client_id}: Loss = {loss:.4f}, Samples = {num_samples}")
    
    # Server aggregation with FedAdam
    server.aggregate_fit(client_results)
    
    # Evaluation every 5 rounds or first round
    if (round_num + 1) % 5 == 0 or round_num == 0:
        eval_results = []
        
        # Update clients with new global model
        global_params = server.get_parameters()
        
        for client in clients:
            client.set_parameters(global_params)
            test_loss, test_acc = client.evaluate()
            eval_results.append((test_loss, test_acc, len(client.test_loader.dataset)))
            print(f"  📊 Client {client.client_id} Test: Loss = {test_loss:.4f}, Accuracy = {test_acc:.4f}")
        
        # Aggregate evaluation results
        avg_test_loss, avg_test_acc = server.aggregate_evaluate(eval_results)
        
        test_losses.append(avg_test_loss)
        test_accuracies.append(avg_test_acc)
        
        print(f"  🌐 Global Test: Loss = {avg_test_loss:.4f}, Accuracy = {avg_test_acc:.4f}")
    
    round_time = time.time() - round_start_time
    print(f"  ⏱️  Round time: {round_time:.2f}s")

total_time = time.time() - start_time
print(f"\n✅ Federated training completed!")
print(f"⏱️  Total training time: {total_time:.2f}s ({total_time/60:.1f} minutes)")
print(f"🎯 Final Global Test Accuracy: {test_accuracies[-1]:.4f}")
# Out:
# 🔄 Round 1/50
#   📱 Client majority: Loss = 0.0190, Samples = 1368440
#   📱 Client minority: Loss = 0.6292, Samples = 7110
#   📊 Client majority Test: Loss = 1.3299, Accuracy = 0.2818
#   📊 Client minority Test: Loss = 1.3644, Accuracy = 0.1124
#   🌐 Global Test: Loss = 1.3301, Accuracy = 0.2809
#   ⏱️  Round time: 45.96s
#
# 🔄 Round 2/50
#   📱 Client majority: Loss = 0.0168, Samples = 1368440
#   📱 Client minority: Loss = 0.6081, Samples = 7110
#   ⏱️  Round time: 42.32s
#
# 🔄 Round 3/50
#   📱 Client majority: Loss = 0.0155, Samples = 1368440
#   📱 Client minority: Loss = 0.5804, Samples = 7110
#   ⏱️  Round time: 45.03s
#
# 🔄 Round 4/50
#   📱 Client majority: Loss = 0.0153, Samples = 1368440
#   📱 Client minority: Loss = 0.5756, Samples = 7110
#   ⏱️  Round time: 43.60s
#
# 🔄 Round 5/50
#   📱 Client majority: Loss = 0.0144, Samples = 1368440
#   📱 Client minority: Loss = 0.5543, Samples = 7110
#   📊 Client majority Test: Loss = 0.8426, Accuracy = 0.9770
#   📊 Client minority Test: Loss = 1.4395, Accuracy = 0.4045
#   🌐 Global Test: Loss = 0.8457, Accuracy = 0.9740
#   ⏱️  Round time: 46.58s
#
# 🔄 Round 6/50
#   📱 Client majority: Loss = 0.0140, Samples = 1368440
#   📱 Client minority: Loss = 0.5479, Samples = 7110
#   ⏱️  Round time: 46.78s
#
# 🔄 Round 7/50
#   📱 Client majority: Loss = 0.0120, Samples = 1368440
#   📱 Client minority: Loss = 0.5587, Samples = 7110
#   ⏱️  Round time: 48.79s
#
# 🔄 Round 8/50
#   📱 Client majority: Loss = 0.0131, Samples = 1368440
#   📱 Client minority: Loss = 0.5653, Samples = 7110
#   ⏱️  Round time: 45.90s
#
# 🔄 Round 9/50
#   📱 Client majority: Loss = 0.0125, Samples = 1368440
#   📱 Client minority: Loss = 0.5864, Samples = 7110
#   ⏱️  Round time: 46.54s
#
# 🔄 Round 10/50
#   📱 Client majority: Loss = 0.0131, Samples = 1368440
#   📱 Client minority: Loss = 0.6216, Samples = 7110
#   📊 Client majority Test: Loss = 0.3070, Accuracy = 0.9651
#   📊 Client minority Test: Loss = 2.4919, Accuracy = 0.3764
#   🌐 Global Test: Loss = 0.3183, Accuracy = 0.9621
#   ⏱️  Round time: 42.25s
#
# 🔄 Round 11/50
#   📱 Client majority: Loss = 0.0109, Samples = 1368440
#   📱 Client minority: Loss = 0.6690, Samples = 7110
#   ⏱️  Round time: 43.32s
#
# 🔄 Round 12/50
#   📱 Client majority: Loss = 0.0130, Samples = 1368440
#   📱 Client minority: Loss = 0.7040, Samples = 7110
#   ⏱️  Round time: 45.00s
#
# 🔄 Round 13/50
#   📱 Client majority: Loss = 0.0118, Samples = 1368440
#   📱 Client minority: Loss = 0.8015, Samples = 7110
#   ⏱️  Round time: 44.85s
#
# 🔄 Round 14/50
#   📱 Client majority: Loss = 0.0125, Samples = 1368440
#   📱 Client minority: Loss = 0.8658, Samples = 7110
#   ⏱️  Round time: 44.20s
#
# 🔄 Round 15/50
#   📱 Client majority: Loss = 0.0094, Samples = 1368440
#   📱 Client minority: Loss = 0.9959, Samples = 7110
#   📊 Client majority Test: Loss = 0.1449, Accuracy = 0.9653
#   📊 Client minority Test: Loss = 5.1502, Accuracy = 0.3708
#   🌐 Global Test: Loss = 0.1708, Accuracy = 0.9622
#   ⏱️  Round time: 41.68s
#
# 🔄 Round 16/50
#   📱 Client majority: Loss = 0.0117, Samples = 1368440
#   📱 Client minority: Loss = 1.0004, Samples = 7110
#   ⏱️  Round time: 43.04s
#
# 🔄 Round 17/50
#   📱 Client majority: Loss = 0.0116, Samples = 1368440
#   📱 Client minority: Loss = 1.0949, Samples = 7110
#   ⏱️  Round time: 43.75s
#
# 🔄 Round 18/50
#   📱 Client majority: Loss = 0.0113, Samples = 1368440
#   📱 Client minority: Loss = 1.1993, Samples = 7110
#   ⏱️  Round time: 46.78s
#
# 🔄 Round 19/50
#   📱 Client majority: Loss = 0.0104, Samples = 1368440
#   📱 Client minority: Loss = 1.2672, Samples = 7110
#   ⏱️  Round time: 46.30s
#
# 🔄 Round 20/50
#   📱 Client majority: Loss = 0.0117, Samples = 1368440
#   📱 Client minority: Loss = 1.3276, Samples = 7110
#   📊 Client majority Test: Loss = 0.1113, Accuracy = 0.9666
#   📊 Client minority Test: Loss = 8.4818, Accuracy = 0.3511
#   🌐 Global Test: Loss = 0.1546, Accuracy = 0.9634
#   ⏱️  Round time: 44.62s
#
# 🔄 Round 21/50
#   📱 Client majority: Loss = 0.0098, Samples = 1368440
#   📱 Client minority: Loss = 1.4076, Samples = 7110
#   ⏱️  Round time: 44.21s
#
# 🔄 Round 22/50
#   📱 Client majority: Loss = 0.0141, Samples = 1368440
#   📱 Client minority: Loss = 1.5447, Samples = 7110
#   ⏱️  Round time: 43.15s
#
# 🔄 Round 23/50
#   📱 Client majority: Loss = 0.0118, Samples = 1368440
#   📱 Client minority: Loss = 1.6438, Samples = 7110
#   ⏱️  Round time: 43.00s
#
# 🔄 Round 24/50
#   📱 Client majority: Loss = 0.0103, Samples = 1368440
#   📱 Client minority: Loss = 1.7408, Samples = 7110
#   ⏱️  Round time: 46.29s
#
# 🔄 Round 25/50
#   📱 Client majority: Loss = 0.0090, Samples = 1368440
#   📱 Client minority: Loss = 1.8259, Samples = 7110
#   📊 Client majority Test: Loss = 0.1020, Accuracy = 0.9686
#   📊 Client minority Test: Loss = 12.3769, Accuracy = 0.3090
#   🌐 Global Test: Loss = 0.1655, Accuracy = 0.9652
#   ⏱️  Round time: 43.76s
#
# 🔄 Round 26/50
#   📱 Client majority: Loss = 0.0105, Samples = 1368440
#   📱 Client minority: Loss = 1.9122, Samples = 7110
#   ⏱️  Round time: 44.30s
#
# 🔄 Round 27/50
#   📱 Client majority: Loss = 0.0103, Samples = 1368440
#   📱 Client minority: Loss = 1.9869, Samples = 7110
#   ⏱️  Round time: 42.28s
#
# 🔄 Round 28/50
#   📱 Client majority: Loss = 0.0104, Samples = 1368440
#   📱 Client minority: Loss = 2.1821, Samples = 7110
#   ⏱️  Round time: 42.40s
#
# 🔄 Round 29/50
#   📱 Client majority: Loss = 0.0087, Samples = 1368440
#   📱 Client minority: Loss = 2.2510, Samples = 7110
#   ⏱️  Round time: 41.92s
#
# 🔄 Round 30/50
#   📱 Client majority: Loss = 0.0092, Samples = 1368440
#   📱 Client minority: Loss = 2.3723, Samples = 7110
#   📊 Client majority Test: Loss = 0.0877, Accuracy = 0.9695
#   📊 Client minority Test: Loss = 17.1082, Accuracy = 0.3062
#   🌐 Global Test: Loss = 0.1758, Accuracy = 0.9661
#   ⏱️  Round time: 41.67s
#
# 🔄 Round 31/50
#   📱 Client majority: Loss = 0.0090, Samples = 1368440
#   📱 Client minority: Loss = 2.4603, Samples = 7110
#   ⏱️  Round time: 42.54s
#
# 🔄 Round 32/50
#   📱 Client majority: Loss = 0.0084, Samples = 1368440
#   📱 Client minority: Loss = 2.6973, Samples = 7110
#   ⏱️  Round time: 41.01s
#
# 🔄 Round 33/50
#   📱 Client majority: Loss = 0.0093, Samples = 1368440
#   📱 Client minority: Loss = 2.7909, Samples = 7110
#   ⏱️  Round time: 229.47s
#
# 🔄 Round 34/50
#   📱 Client majority: Loss = 0.0101, Samples = 1368440
#   📱 Client minority: Loss = 2.9037, Samples = 7110
#   ⏱️  Round time: 46.47s
#
# 🔄 Round 35/50
#   📱 Client majority: Loss = 0.0082, Samples = 1368440
#   📱 Client minority: Loss = 3.0991, Samples = 7110
#   📊 Client majority Test: Loss = 0.0771, Accuracy = 0.9767
#   📊 Client minority Test: Loss = 23.1573, Accuracy = 0.3146
#   🌐 Global Test: Loss = 0.1966, Accuracy = 0.9732
#   ⏱️  Round time: 47.06s
#
# 🔄 Round 36/50
#   📱 Client majority: Loss = 0.0075, Samples = 1368440
#   📱 Client minority: Loss = 3.4020, Samples = 7110
#   ⏱️  Round time: 42.83s
#
# 🔄 Round 37/50
#   📱 Client majority: Loss = 0.0096, Samples = 1368440
#   📱 Client minority: Loss = 3.6718, Samples = 7110
#   ⏱️  Round time: 41.01s
#
# 🔄 Round 38/50
#   📱 Client majority: Loss = 0.0100, Samples = 1368440
#   📱 Client minority: Loss = 3.7451, Samples = 7110
#   ⏱️  Round time: 41.94s
#
# 🔄 Round 39/50
#   📱 Client majority: Loss = 0.0091, Samples = 1368440
#   📱 Client minority: Loss = 4.0738, Samples = 7110
#   ⏱️  Round time: 40.49s
#
# 🔄 Round 40/50
#   📱 Client majority: Loss = 0.0081, Samples = 1368440
#   📱 Client minority: Loss = 4.0750, Samples = 7110
#   📊 Client majority Test: Loss = 0.0598, Accuracy = 0.9808
#   📊 Client minority Test: Loss = 29.4242, Accuracy = 0.3174
#   🌐 Global Test: Loss = 0.2118, Accuracy = 0.9774
#   ⏱️  Round time: 44.40s
#
# 🔄 Round 41/50
#   📱 Client majority: Loss = 0.0106, Samples = 1368440
#   📱 Client minority: Loss = 4.5318, Samples = 7110
#   ⏱️  Round time: 41.98s
#
# 🔄 Round 42/50
#   📱 Client majority: Loss = 0.0072, Samples = 1368440
#   📱 Client minority: Loss = 4.5377, Samples = 7110
#   ⏱️  Round time: 42.82s
#
# 🔄 Round 43/50
#   📱 Client majority: Loss = 0.0095, Samples = 1368440
#   📱 Client minority: Loss = 4.6084, Samples = 7110
#   ⏱️  Round time: 42.77s
#
# 🔄 Round 44/50
#   📱 Client majority: Loss = 0.0087, Samples = 1368440
#   📱 Client minority: Loss = 4.8145, Samples = 7110
#   ⏱️  Round time: 40.88s
#
# 🔄 Round 45/50
#   📱 Client majority: Loss = 0.0101, Samples = 1368440
#   📱 Client minority: Loss = 5.0344, Samples = 7110
#   📊 Client majority Test: Loss = 0.0463, Accuracy = 0.9835
#   📊 Client minority Test: Loss = 35.3138, Accuracy = 0.3174
#   🌐 Global Test: Loss = 0.2288, Accuracy = 0.9800
#   ⏱️  Round time: 44.21s
#
# 🔄 Round 46/50
#   📱 Client majority: Loss = 0.0085, Samples = 1368440
#   📱 Client minority: Loss = 5.3872, Samples = 7110
#   ⏱️  Round time: 41.39s
#
# 🔄 Round 47/50
#   📱 Client majority: Loss = 0.0080, Samples = 1368440
#   📱 Client minority: Loss = 5.6671, Samples = 7110
#   ⏱️  Round time: 43.03s
#
# 🔄 Round 48/50
#   📱 Client majority: Loss = 0.0084, Samples = 1368440
#   📱 Client minority: Loss = 5.6803, Samples = 7110
#   ⏱️  Round time: 1982.15s
#
# 🔄 Round 49/50
#   📱 Client majority: Loss = 0.0089, Samples = 1368440
#   📱 Client minority: Loss = 6.1193, Samples = 7110
#   ⏱️  Round time: 41.03s
#
# 🔄 Round 50/50
#   📱 Client majority: Loss = 0.0090, Samples = 1368440
#   📱 Client minority: Loss = 5.8685, Samples = 7110
#   📊 Client majority Test: Loss = 0.0420, Accuracy = 0.9845
#   📊 Client minority Test: Loss = 41.2208, Accuracy = 0.3146
#   🌐 Global Test: Loss = 0.2551, Accuracy = 0.9810
#   ⏱️  Round time: 43.67s
#
# ✅ Federated training completed!
# ⏱️  Total training time: 4311.44s (71.9 minutes)
# 🎯 Final Global Test Accuracy: 0.9810
